# %% [markdown]
# Câu 1: Bạn hãy xây dựng một hàm nhận tham số truyền vào là 1 chuỗi ký tự bất kỳ. Hàm kiểm tra và trả về kết quả
# chuỗi trên là một đoạn password hợp lệ hay không, biết rằng password hợp lệ cần thoả mãn các tiêu chí:
# - Chứa 1 ký tự đặc biệt trong các ký tự !, @, #, $, ^
# - Chứa ít nhất một ký tự số
# - Chứa ít nhất một ký tự chữ cái viết hoa
# - Chứa ít nhất một ký tự chữ cái viết thường
# - Độ dài từ 8 - 15 ký tự

# %%
def is_valid_password(password):
  if len(password) < 8 or len(password) > 15:
    return False

  special_characters = "!@#$^"
  for char in password:
    if char in special_characters:
      break
  else:
    return False

  for char in password:
    if char.isdigit():
      break
  else:
    return False

  for char in password:
    if char.isupper():
      break
  else:
    return False

  for char in password:
    if char.islower():
      break
  else:
    return False

  return True

password = input("Nhập mật khẩu của bạn: ")
if is_valid_password(password):
    print("Mật khẩu hợp lệ.")
else:
    print("Mật khẩu không hợp lệ.")
# Out:
# Nhập mật khẩu của bạn: 123
# Mật khẩu không hợp lệ.

# %% [markdown]
# Câu 2: Bạn hãy đọc file dữ liệu với pandas. Và giải quyết các câu sau:
# A. Bạn hãy lấy ra các đơn hàng thuộc Branch A hoặc C (0.25đ)
# B. Bạn hãy tìm ra các đơn hàng mua sản phẩm là ‘Health and beauty’ hoặc ‘Sports and travel’ (0.25đ)
# C. Cột InvoiceID, giá trị được lưu trữ theo dạng XXX-StoreID-XXXX.
# Bạn hãy tạo 1 dataframe mới gồm các cột như trên file và tạo thêm một cột StoreID được tách từ InvoiceID.
# Sau đó tính tổng doanh số của từng StoreID đó. (0.25đ)

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/supermarket_sales.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Date           1000 non-null   object
#  9   Time           1000 non-null   object
#  10  Payment        1000 non-null   object
#  11  cogs           1000 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs
# 0      Ewallet  522.83
# 1         Cash   76.40
# 2  Credit card  324.31
# 3      Ewallet  465.76
# 4      Ewallet  604.17

# %%
df.loc[(df['Branch'] == 'A') | (df['Branch'] == 'C')]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date   Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08
# 1    Electronic accessories       15.28         5   3/8/2019  10:29
# 2        Home and lifestyle       46.33         7   3/3/2019  13:23
# ...

# %%
df.loc[(df['Product line'].str.lower() == 'health and beauty') | (df['Product line'].str.lower() == 'sports and travel')]
# Out:
#       Invoice ID Branch       City Customer type  Gender       Product line  \
# 0    750-67-8428      A     Yangon        Member  Female  Health and beauty
# 3    123-19-1176      A     Yangon        Member    Male  Health and beauty
# 4    373-73-7910      A     Yangon        Normal    Male  Sports and travel
# 8    665-32-9167      A     Yangon        Member  Female  Health and beauty
# 14   829-34-3910      A     Yangon        Normal  Female  Health and beauty
# ..           ...    ...        ...           ...     ...                ...
# 986  764-44-8999      B   Mandalay        Normal  Female  Health and beauty
# 987  552-44-5977      B   Mandalay        Member    Male  Health and beauty
# 989  430-53-4718      B   Mandalay        Member    Male  Health and beauty
# 991  602-16-6955      B   Mandalay        Normal  Female  Sports and travel
# 995  233-67-5758      C  Naypyitaw        Normal    Male  Health and beauty
#
# ...

# %%
new_df = df.copy()
new_df['StoreID'] = new_df['Invoice ID'].str.split('-', expand=True)[1]
new_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs StoreID
# 0      Ewallet  522.83      67
# 1         Cash   76.40      31
# 2  Credit card  324.31      41
# 3      Ewallet  465.76      19
# 4      Ewallet  604.17      73

# %%
new_df['TotalSales'] = new_df['Unit price'] * new_df['Quantity']
total_sales_by_storeid = new_df.groupby('StoreID')['TotalSales'].sum().reset_index()
total_sales_by_storeid
# Out:
#    StoreID  TotalSales
# 0       01     5418.11
# 1       02     3864.69
# 2       03     4023.86
# 3       04     5441.09
# 4       05     2578.99
# ..     ...         ...
# 94      95     3070.69
# 95      96     4681.04
# 96      97      916.60
# 97      98     3706.48
# 98      99     1627.19
#
# [99 rows x 2 columns]

# %%
new_df = new_df.merge(total_sales_by_storeid, on='StoreID', how='left')

# %%
new_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs StoreID  TotalSales
# 0      Ewallet  522.83      67      522.83
# 1         Cash   76.40      31       76.40
# 2  Credit card  324.31      41      324.31
# 3      Ewallet  465.76      19      465.76
# ...

# %% [markdown]
# Câu 3: Bạn hãy xây dựng một hàm nhận tham số truyền vào là một danh sách bất kỳ chỉ chứa các số. Hàm tính toán
# và trả về số lớn nhì trong danh sách. Với trường hợp danh sách gồm các số bằng nhau, hàm trả về số lớn nhất. Nếu
# có nhiều giá trị bằng số lớn nhì trong danh sách, hàm trả về 1 giá trị duy nhất.(1.5đ)
#
# Ví dụ:
# - Với danh sách [1,1,1,1,1,1] -> Hàm trả về 1
# - Với danh sách [1,2,1,1,2,3] -> Hàm trả về 2

# %%
input_string = input("Nhập dãy số (cách nhau bằng dấu cách): ")

strings = input_string.split()
numbers_list = []
for s in strings:
  numbers_list.append(float(s))

def second_largest(nums):
  unique_nums = list(set(nums))
  if len(unique_nums) < 2:
    return unique_nums[0] if unique_nums else None

  largest = second = float('-inf')

  for num in unique_nums:
    if num > largest:
      second = largest
      largest = num
    elif largest > num > second:
      second = num
  return second if second != float('-inf') else largest

result = second_largest(numbers_list)

print("Số lớn nhì trong danh sách là:", result)
# Out:
# Nhập dãy số (cách nhau bằng dấu cách): 2 5 7 5 4 4 5 7
# Số lớn nhì là: 5.0
